# %%
from langchain_groq import ChatGroq
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
from langchain.prompts import ChatPromptTemplate
import requests
from bs4 import BeautifulSoup
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough
from langchain.utilities import DuckDuckGoSearchAPIWrapper
import json

RESULTS_PER_QUESTION = 2

ddg_search = DuckDuckGoSearchAPIWrapper()

def webSearch(query: str, nums_results: int=RESULTS_PER_QUESTION):
    results = ddg_search.results(query, nums_results)
    return [r["link"] for r in results]


template = """{context} 
-----------
Using the above text, answer in short the following question: 
> {question}
-----------
if the question cannot be answered using the text, imply summarize the text. Include all factual information, numbers, stats etc if available."""

summarize_prompt = ChatPromptTemplate.from_template(template=template)

# function for scraping the text of the website
def scrapeText(url: str):
    try:
        response = requests.get(url=url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            page_text = soup.get_text(separator=" ", strip=True)
            return page_text
        else:
            return f"Failed to retrieve webpage: Status code {response.status_code}"
    except Exception as e:
        print(e)
        return f"Failed to retrieve the webpage: {e}"

scrape_and_summarize_chain = RunnablePassthrough.assign(
    context = lambda x: scrapeText(x["url"])[:5000]
) | summarize_prompt | model | StrOutputParser()

web_search_chain = RunnablePassthrough.assign(
    urls = lambda x: webSearch(x["question"])
)| (lambda x: [{"question": x["question"], "url": u} for u in x["urls"]]) | scrape_and_summarize_chain.map()


SEARCH_PROMPT = ChatPromptTemplate.from_messages(
    [
        (
            "user",
            "Write 2 google search queries to search online that are form an"
            "objective opinion from the following: {question}\n"
            "You must respond with a list of strings in the following format"
            '["query1", "query2", "query3"]',
        ),
    ]
)

search_question_chain = SEARCH_PROMPT | model | StrOutputParser() | json.loads

# chain = search_question_chain | (lambda x: [{"question": q} for q in x]) |web_search_chain.map()

WRITER_SYSTEM_TEMPLATE = "You are an AI critical thinker research assistant. Your sole purpose is to write well written, critically acclaimed, objective and structured reports on given text."

RESEARCH_REPORT_TEMPLATE = """Information:
--------
{research_summary}
--------
Using the above information, answer the following question or topic: "{question}" in a detailed report -- \
The report should focus on the answer to the question, should be well structured, informative, \
in depth, with facts and numbers if available and a minimum of 1,200 words.
You should strive to write the report as long as you can using all relevant and necessary information provided.
You must write the report with markdown syntax.
You MUST determine your own concrete and valid opinion based on the given information. Do NOT deter to general and meaningless conclusions.
Write all used source urls at the end of the report, and make sure to not add duplicated sources, but only one reference for each.
You must write the report in apa format.
Please do your best, this is very important to my career."""

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", WRITER_SYSTEM_TEMPLATE),
        ("user", RESEARCH_REPORT_TEMPLATE),
    ]
)

def collapse_lists(list_of_lists):
    content = []
    for l in list_of_lists:
        content.append("\n\n".join(l))
    return "\n\n".join(content)

chain = RunnablePassthrough.assign(
    research_summary = web_search_chain | collapse_lists
) | prompt | model | StrOutputParser()

response = chain.invoke(
    {
        "question": "What is the difference between langchain and langgraph?"
    }
)

# %%
print(response)
# Out:
# # Introduction
# The main difference between LangChain and LangGraph is their approach to integrating Language Models (LLMs) and their suitability for various use cases. LangChain is designed for sequential workflows, utilizing a Directed Acyclic Graph (DAG) structure, making it ideal for tasks that require a predefined order of operations. On the other hand, LangGraph excels in workflows that necessitate extensive customization, flexibility, and the handling of complex, non-linear interactions, leveraging a more flexible graph structure.
#
# ## Background
# Language Models (LLMs) have revolutionized the field of natural language processing, enabling machines to understand, generate, and interact with human language at an unprecedented level. The integration of these models into workflows and applications has become a critical aspect of leveraging their capabilities. Two frameworks that have emerged to facilitate this integration are LangChain and LangGraph. Each has its unique strengths, weaknesses, and use cases, making the choice between them dependent on the specific requirements of the project or application.
#
# ## LangChain
# LangChain is characterized by its use of a Directed Acyclic Graph (DAG) structure. This means that the workflow is designed to flow in one direction, with no cycles or loops, which simplifies the execution and debugging of tasks. LangChain is particularly suited for sequential workflows where the order of operations is predefined and relatively straightforward. It offers ease of integration with LLMs, making it accessible for developers to create applications that can perform tasks like text generation, question-answering, and text classification with minimal setup.
#
# One of the key benefits of LangChain is its simplicity and ease of use. It allows developers to focus on the logic of their application without needing to delve deeply into the complexities of graph structures or parallel processing. This simplicity also translates into faster development times and easier maintenance of the codebase. Furthermore, LangChain's sequential nature makes it more predictable and easier to debug, as the flow of data and control is linear and straightforward.
#
# However, the strengths of LangChain also highlight its limitations. The DAG structure, while beneficial for simplicity and predictability, can become restrictive when dealing with complex, dynamic workflows that require flexibility and the ability to handle non-linear interactions. In such cases, the rigid structure of LangChain can hinder the application's ability to adapt to changing conditions or user inputs that do not follow a predetermined sequence.
#
# ## LangGraph
# LangGraph, on the other hand, is designed to handle more complex workflows that require a high degree of flexibility and customization. It achieves this through the use of a flexible graph structure that can accommodate loops, conditional statements, and dynamic transitions between different states or tasks. This flexibility makes LangGraph particularly well-suited for applications that involve multi-agent systems, dynamic decision-making processes, or workflows that require extensive customization based on user input or external factors.
#
# The flexibility of LangGraph comes at the cost of increased complexity. Setting up and managing workflows in LangGraph can be more challenging due to the potential for cycles and the need to manage state transitions explicitly. This complexity can lead to longer development times and requires developers to have a deeper understanding of graph structures and parallel processing. However, for applications that require this level of sophistication, LangGraph provides unparalleled capabilities, allowing for the creation of highly dynamic and interactive systems that can adapt to a wide range of scenarios and user behaviors.
#
# ## Comparison
# When comparing LangChain and LangGraph, several key differences emerge:
# - **Structure**: LangChain uses a DAG structure, which is linear and predictable, whereas LangGraph utilizes a more flexible graph structure that can accommodate complexity and non-linearity.
# - **Use Cases**: LangChain is ideal for sequential, straightforward workflows, while LangGraph is better suited for complex, dynamic workflows that require flexibility and customization.
# - **Ease of Use**: LangChain is generally easier to use and integrate, especially for developers without extensive experience in graph structures or parallel processing. LangGraph, while more powerful, requires a deeper understanding of its underlying mechanics.
# - **Scalability and Performance**: Both frameworks have their strengths in terms of scalability and performance, but LangGraph's ability to handle complex workflows can make it more suitable for large-scale applications that require dynamic interaction and adaptation.
#
# ## Conclusion
# In conclusion, the choice between LangChain and LangGraph depends on the specific needs and requirements of the project. For applications that involve straightforward, sequential workflows, LangChain offers a simple, efficient, and easy-to-use solution. However, for projects that require handling complex, dynamic interactions, or workflows that demand a high degree of flexibility and customization, LangGraph provides the necessary tools and structures to achieve these goals.
#
# While LangChain excels in simplicity and predictability, LangGraph offers unparalleled flexibility and the ability to manage complex workflows. Understanding the strengths and weaknesses of each framework is crucial for making an informed decision that aligns with the project's objectives and requirements.
#
# Ultimately, the development community benefits from having both LangChain and LangGraph as options, as they cater to different needs and use cases, promoting innovation and efficiency in the integration of LLMs into various applications and workflows.
#
# ## References
# No specific URLs or references were provided in the prompt. However, for further information on LangChain and LangGraph, readers can explore the official documentation and community resources for these frameworks, which typically include detailed guides, tutorials, and examples of how to use them effectively in different projects and applications.
#
# Note: Since no specific sources were mentioned in the prompt, and to adhere to the APA format requirement for citing sources, it's essential to consult and cite relevant academic or technical publications, official documentation, or reputable online resources when researching LangChain and LangGraph in a real-world context.
